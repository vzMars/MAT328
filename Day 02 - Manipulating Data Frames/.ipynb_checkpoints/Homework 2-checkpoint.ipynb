# %% [markdown]
# Marcos Gonzalez
# Homework #2
# 2/8/21

# %% [markdown]
# # Homework 2: slicing, sorting, and grouping
#
# This homework uses the 2020 green taxi trip data filtered to only be trips with a pickup date and time on Feb. 4, 2020.  Download the file from Blackboard or from GitHub:
# [https://raw.githubusercontent.com/megan-owen/MAT328-Techniques_in_Data_Science/main/data/Feb4_2020_Green_Taxi_Trip_Data.csv](https://raw.githubusercontent.com/megan-owen/MAT328-Techniques_in_Data_Science/main/data/Feb4_2020_Green_Taxi_Trip_Data.csv).
#
# The original unfiltered dataset is available at [https://data.cityofnewyork.us/Transportation/2020-Green-Taxi-Trip-Data-January-June-/pkmi-4kfn](https://data.cityofnewyork.us/Transportation/2020-Green-Taxi-Trip-Data-January-June-/pkmi-4kfn).
#
# Answer the following questions for the data, showing all outputs of your code in the notebook.
#
# All plots should have an appropriate title and axis labels.
#
# ### Question 0:  Load the data
#
# Put any import statements, and load the green taxi trip data from Feb. 4, 202 from the CSV file or URL here.  The column `lpep_pickup_datetime` should be stored as a DateTime object.
#
# Note:  To convert the `lpep_pickup_datetime` column to a `datetime` object, you may have to add the parameter `parse_dates = ["lpep_pickup_datetime"]` to `read_csv()`.
# ex. `taxi = pd.read_csv("taxi.csv", parse_dates = ["lpep_pickup_datetime"])` instead of using the method presented in the labs.  I am honestly not sure why.

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

taxi = pd.read_csv("Feb4_2020_Green_Taxi_Trip_Data.csv", parse_dates = ["lpep_pickup_datetime"])
taxi
# Out:
#        VendorID lpep_pickup_datetime   lpep_dropoff_datetime  \
# 0           2.0  2020-02-04 00:00:07  02/04/2020 12:08:01 AM
# 1           2.0  2020-02-04 00:00:20  02/04/2020 12:13:44 AM
# 2           2.0  2020-02-04 00:00:42  02/04/2020 12:03:29 AM
# 3           2.0  2020-02-04 00:01:00  02/04/2020 12:13:15 AM
# 4           NaN  2020-02-04 00:01:00  02/04/2020 12:31:00 AM
# ...         ...                  ...                     ...
# 13976       2.0  2020-02-04 23:57:53  02/05/2020 12:01:00 AM
# 13977       2.0  2020-02-04 23:58:14  02/05/2020 12:09:00 AM
# 13978       2.0  2020-02-04 23:58:29  02/05/2020 12:05:29 AM
# 13979       2.0  2020-02-04 23:59:37  02/05/2020 12:02:39 AM
# 13980       2.0  2020-02-04 23:59:51  02/05/2020 12:24:06 AM
#
#       store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                      N         1.0            42           152
# 1                      N         1.0            25           188
# 2                      N         1.0           166           152
# 3                      N         1.0            82           173
# 4                    NaN         NaN           136            90
# ...                  ...         ...           ...           ...
# 13976                  N         1.0           112           255
# 13977                  N         1.0            97            52
# 13978                  N         1.0            25           181
# 13979                  N         1.0             7             7
# 13980                  N         1.0           129            82
#
#        passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 0                  1.0           1.21         7.00   0.50      0.5
# 1                  1.0           3.28        12.50   0.50      0.5
# 2                  1.0           0.68         4.00   0.50      0.5
# 3                  1.0           1.89         9.50   0.50      0.5
# 4                  NaN          12.80        51.55   2.75      0.0
# ...                ...            ...          ...    ...      ...
# 13976              1.0           0.64         4.50   0.50      0.5
# 13977              1.0           1.77         9.00   0.50      0.5
# 13978              1.0           1.80         7.50   0.50      0.5
# 13979              1.0           0.69         4.50   0.50      0.5
# 13980              1.0           1.60        13.50   0.50      0.5
#
#        tip_amount  tolls_amount  ehail_fee  improvement_surcharge  \
# 0            0.00           0.0        NaN                    0.3
# 1            0.00           0.0        NaN                    0.3
# 2            0.00           0.0        NaN                    0.3
# 3            1.50           0.0        NaN                    0.3
# 4            0.00           0.0        NaN                    0.3
# ...           ...           ...        ...                    ...
# 13976        0.00           0.0        NaN                    0.3
# 13977        0.00           0.0        NaN                    0.3
# 13978        2.64           0.0        NaN                    0.3
# 13979        0.00           0.0        NaN                    0.3
# 13980        0.00           0.0        NaN                    0.3
#
#        total_amount  payment_type  trip_type  congestion_surcharge
# 0              8.30           1.0        1.0                   0.0
# 1             13.80           2.0        1.0                   0.0
# 2              5.30           2.0        1.0                   0.0
# 3             12.30           1.0        1.0                   0.0
# 4             54.60           NaN        NaN                   NaN
# ...             ...           ...        ...                   ...
# 13976          5.80           2.0        1.0                   0.0
# 13977         10.30           1.0        1.0                   0.0
# 13978         11.44           1.0        1.0                   0.0
# 13979          5.80           2.0        1.0                   0.0
# 13980         14.80           2.0        1.0                   0.0
#
# [13981 rows x 20 columns]

# %% [markdown]
# ### Question 1
#
# Create a new dataframe called `taxi2` containing only the columns `lpep_pickup_datetime`, `passenger_count`, `trip_distance`, and `total_amount`.

# %%
taxi2 = taxi[["lpep_pickup_datetime","passenger_count","trip_distance","total_amount"]]
taxi2
# Out:
#       lpep_pickup_datetime  passenger_count  trip_distance  total_amount
# 0      2020-02-04 00:00:07              1.0           1.21          8.30
# 1      2020-02-04 00:00:20              1.0           3.28         13.80
# 2      2020-02-04 00:00:42              1.0           0.68          5.30
# 3      2020-02-04 00:01:00              1.0           1.89         12.30
# 4      2020-02-04 00:01:00              NaN          12.80         54.60
# ...                    ...              ...            ...           ...
# 13976  2020-02-04 23:57:53              1.0           0.64          5.80
# 13977  2020-02-04 23:58:14              1.0           1.77         10.30
# 13978  2020-02-04 23:58:29              1.0           1.80         11.44
# 13979  2020-02-04 23:59:37              1.0           0.69          5.80
# 13980  2020-02-04 23:59:51              1.0           1.60         14.80
#
# [13981 rows x 4 columns]

# %% [markdown]
# ### Question 2
#
# Find the row with the longest trip distance and then use slicing to extract just that row.
#
# When did the trip take place and how much did it cost?
#
# Hint:  Use `idxmax()` to find the row index of the longest trip distance.

# %%
taxi2[["trip_distance"]].idxmax()
# Out:
# trip_distance    9629
# dtype: int64

# %%
taxi2.loc[9629]
# Out:
# lpep_pickup_datetime    2020-02-04 17:28:19
# passenger_count                           1
# trip_distance                         39.46
# total_amount                         170.82
# Name: 9629, dtype: object

# %% [markdown]
# This trip took place on 2/4/20 at 17:28 and cost $170.82.

# %% [markdown]
# ### Question 3
#
# Create a new DataFrame called `sorted_taxi` that is sorted in ascending order by passenger count, then by trip distance.
#
# What do you notice about the `passenger_count` column at the beginning and end of this new DataFrame?

# %%
sorted_taxi_by_pass = taxi2.sort_values(["passenger_count","trip_distance"])
sorted_taxi_by_pass
# Out:
#       lpep_pickup_datetime  passenger_count  trip_distance  total_amount
# 7019   2020-02-04 14:38:08              0.0           0.00         15.30
# 12562  2020-02-04 20:53:44              0.0           0.00         21.36
# 2930   2020-02-04 09:38:24              0.0           0.12         11.16
# 11792  2020-02-04 19:52:21              0.0           0.80          6.30
# 12978  2020-02-04 21:35:49              0.0           0.90          6.80
# ...                    ...              ...            ...           ...
# 7666   2020-02-04 15:25:00              NaN          30.25         61.55
# 482    2020-02-04 04:58:00              NaN          30.81         98.50
# 6630   2020-02-04 14:09:00              NaN          30.82         61.55
# 3464   2020-02-04 10:14:00              NaN          31.39         82.67
# 7708   2020-02-04 15:29:00              NaN          31.69         81.00
#
# [13981 rows x 4 columns]

# %% [markdown]
# The passenger_count column at the beginning is 0 and at the end is NaN.

# %% [markdown]
# ### Question 4
#
# Compute the mean trip distance for each possible number of passengers.  For what number of passengers is the mean trip distance the longest?

# %%
grouped_taxi = sorted_taxi_by_pass.groupby("passenger_count").mean()
grouped_taxi["trip_distance"]
# Out:
# passenger_count
# 0.0    1.560000
# 1.0    2.523879
# 2.0    2.640362
# 3.0    2.729615
# 4.0    1.955172
# 5.0    2.875179
# 6.0    2.246034
# 8.0    0.000000
# Name: trip_distance, dtype: float64

# %% [markdown]
# 5 passengers has the longest mean trip distance.

# %% [markdown]
# ### Question 5
#
# Compute the median trip distance for each hour (0-23) of Feb. 4, 2020, and plot a line graph of these medians.
#
# What trends do you notice in the graph?
#
# The hour of DateTime data can be accessed with `dt.hour`

# %% [markdown]
# - sort from 00:00 - 23:59

# %%
sorted_taxi_by_hour = taxi2.sort_values(["lpep_pickup_datetime"])
sorted_taxi_by_hour
# Out:
#       lpep_pickup_datetime  passenger_count  trip_distance  total_amount
# 0      2020-02-04 00:00:07              1.0           1.21          8.30
# 1      2020-02-04 00:00:20              1.0           3.28         13.80
# 2      2020-02-04 00:00:42              1.0           0.68          5.30
# 3      2020-02-04 00:01:00              1.0           1.89         12.30
# 4      2020-02-04 00:01:00              NaN          12.80         54.60
# ...                    ...              ...            ...           ...
# 13976  2020-02-04 23:57:53              1.0           0.64          5.80
# 13977  2020-02-04 23:58:14              1.0           1.77         10.30
# 13978  2020-02-04 23:58:29              1.0           1.80         11.44
# 13979  2020-02-04 23:59:37              1.0           0.69          5.80
# 13980  2020-02-04 23:59:51              1.0           1.60         14.80
#
# [13981 rows x 4 columns]

# %% [markdown]
# - group by year and compute median

# %%
grouped_taxi2 = sorted_taxi_by_hour.groupby(sorted_taxi_by_hour["lpep_pickup_datetime"].dt.hour).median()
grouped_taxi2
# Out:
#                       passenger_count  trip_distance  total_amount
# lpep_pickup_datetime
# 0                                 1.0          1.850         10.80
# 1                                 1.0          1.685         10.30
# 2                                 1.0          1.445          9.55
# 3                                 1.0          2.020         10.00
# 4                                 1.0          3.205         20.87
# 5                                 1.0          4.910         27.91
# 6                                 1.0          4.760         26.84
# 7                                 1.0          2.150         18.48
# 8                                 1.0          1.950         15.75
# 9                                 1.0          1.960         17.16
# 10                                1.0          2.025         15.55
# 11                                1.0          2.395         18.63
# 12                                1.0          2.110         17.80
# 13                                1.0          2.140         16.13
# 14                                1.0          2.210         16.93
# 15                                1.0          2.290         18.00
# 16                                1.0          2.000         16.56
# 17                                1.0          1.700         13.80
# 18                                1.0          1.650         12.80
# 19                                1.0          1.720         12.36
# 20                                1.0          1.700         11.80
# 21                                1.0          2.035         12.96
# 22                                1.0          2.080         12.95
# 23                                1.0          2.060         12.00

# %% [markdown]
# - pull trip_distance column and line plot

# %%
grouped_taxi2.plot(y = "trip_distance")
plt.title("Median Trip Distance For Each Hour Of 2/4/2020")
plt.xlabel("Hour")
plt.ylabel("Median Trip Distance")
# Out:
# Text(0, 0.5, 'Median Trip Distance')

# %% [markdown]
# There is a rise in trip distance early in the morning which might have to do with people heading to work or coming back from work. Since it early in the morning the trains might be running slower so people are willing to take pay more to get to their house/work faster.
