# %% [markdown]
# Marcos Gonzalez
# Homework #5
# 2/21/21

# %% [markdown]
# # Homework 5
#
# We will also use the FBI NICS Firearms Background Check data from Labs 2 and 5.
#
# Remember all plots should have informative axis labels and a title.
#
# ### Question 0: Loading the data
#
# As in Lab 5, load the data and convert the `month` column into DateTime objects.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
pd.set_option('display.max_columns', None)

# %%
guns = pd.read_csv("https://raw.githubusercontent.com/BuzzFeedNews/nics-firearm-background-checks/master/data/nics-firearm-background-checks.csv")
guns.head()
# Out:
#      month       state   permit  permit_recheck  handgun  long_gun   other  \
# 0  2021-01     Alabama  39955.0           464.0  33563.0   23477.0  2309.0
# 1  2021-01      Alaska    283.0             4.0   3989.0    3574.0   563.0
# 2  2021-01     Arizona   9237.0          1085.0  29336.0   14430.0  2339.0
# 3  2021-01    Arkansas   3231.0          1028.0  11993.0   10043.0   715.0
# 4  2021-01  California  19078.0          6462.0  55103.0   36179.0  6807.0
#
#    multiple  admin  prepawn_handgun  prepawn_long_gun  prepawn_other  \
# 0      1568    0.0             26.0              11.0            2.0
# 1       262    0.0              1.0               1.0            1.0
# 2      1795    0.0             12.0               7.0            2.0
# 3       596   15.0             15.0              15.0            2.0
# 4         0    0.0              2.0               0.0            0.0
#
#    redemption_handgun  redemption_long_gun  redemption_other  \
# 0              2820.0               1301.0               5.0
# 1               149.0                101.0               1.0
# 2              1519.0                586.0               9.0
# 3              1261.0               1130.0               4.0
# 4               422.0                340.0              13.0
#
#    returned_handgun  returned_long_gun  returned_other  rentals_handgun  \
# 0              26.0                0.0             0.0              0.0
# 1              31.0               31.0             0.0              0.0
# 2             139.0                6.0             0.0              0.0
# 3               0.0                0.0             0.0              0.0
# 4             807.0              490.0            86.0              0.0
#
#    rentals_long_gun  private_sale_handgun  private_sale_long_gun  \
# 0               0.0                  25.0                   34.0
# 1               0.0                   7.0                   18.0
# 2               0.0                  22.0                   17.0
# 3               0.0                  21.0                   13.0
# 4               0.0                5744.0                 2282.0
#
#    private_sale_other  return_to_seller_handgun  return_to_seller_long_gun  \
# 0                14.0                       0.0                        2.0
# 1                 2.0                       0.0                        0.0
# 2                 3.0                       2.0                        0.0
# 3                 2.0                       1.0                        0.0
# 4               528.0                      55.0                       33.0
#
#    return_to_seller_other  totals
# 0                     0.0  105602
# 1                     0.0    9018
# 2                     2.0   60548
# 3                     0.0   30085
# 4                     1.0  134432

# %%
guns["month"] = pd.to_datetime(guns["month"])
guns
# Out:
#            month          state   permit  permit_recheck  handgun  long_gun  \
# 0     2021-01-01        Alabama  39955.0           464.0  33563.0   23477.0
# 1     2021-01-01         Alaska    283.0             4.0   3989.0    3574.0
# 2     2021-01-01        Arizona   9237.0          1085.0  29336.0   14430.0
# 3     2021-01-01       Arkansas   3231.0          1028.0  11993.0   10043.0
# 4     2021-01-01     California  19078.0          6462.0  55103.0   36179.0
# ...          ...            ...      ...             ...      ...       ...
# 14680 1998-11-01       Virginia      0.0             NaN     14.0       2.0
# 14681 1998-11-01     Washington      1.0             NaN     65.0     286.0
# 14682 1998-11-01  West Virginia      3.0             NaN    149.0     251.0
# 14683 1998-11-01      Wisconsin      0.0             NaN     25.0     214.0
# 14684 1998-11-01        Wyoming      8.0             NaN     45.0      49.0
#
#         other  multiple  admin  prepawn_handgun  prepawn_long_gun  \
# 0      2309.0      1568    0.0             26.0              11.0
# 1       563.0       262    0.0              1.0               1.0
# 2      2339.0      1795    0.0             12.0               7.0
# 3       715.0       596   15.0             15.0              15.0
# 4      6807.0         0    0.0              2.0               0.0
# ...       ...       ...    ...              ...               ...
# 14680     NaN         8    0.0              NaN               NaN
# 14681     NaN         8    1.0              NaN               NaN
# 14682     NaN         5    0.0              NaN               NaN
# 14683     NaN         2    0.0              NaN               NaN
# 14684     NaN         5    0.0              NaN               NaN
#
#        prepawn_other  redemption_handgun  redemption_long_gun  \
# 0                2.0              2820.0               1301.0
# 1                1.0               149.0                101.0
# 2                2.0              1519.0                586.0
# 3                2.0              1261.0               1130.0
# 4                0.0               422.0                340.0
# ...              ...                 ...                  ...
# 14680            NaN                 NaN                  NaN
# 14681            NaN                 NaN                  NaN
# 14682            NaN                 NaN                  NaN
# 14683            NaN                 NaN                  NaN
# 14684            NaN                 NaN                  NaN
#
#        redemption_other  returned_handgun  returned_long_gun  returned_other  \
# 0                   5.0              26.0                0.0             0.0
# 1                   1.0              31.0               31.0             0.0
# 2                   9.0             139.0                6.0             0.0
# 3                   4.0               0.0                0.0             0.0
# 4                  13.0             807.0              490.0            86.0
# ...                 ...               ...                ...             ...
# 14680               NaN               NaN                NaN             NaN
# 14681               NaN               NaN                NaN             NaN
# 14682               NaN               NaN                NaN             NaN
# 14683               NaN               NaN                NaN             NaN
# 14684               NaN               NaN                NaN             NaN
#
#        rentals_handgun  rentals_long_gun  private_sale_handgun  \
# 0                  0.0               0.0                  25.0
# 1                  0.0               0.0                   7.0
# 2                  0.0               0.0                  22.0
# 3                  0.0               0.0                  21.0
# 4                  0.0               0.0                5744.0
# ...                ...               ...                   ...
# 14680              NaN               NaN                   NaN
# 14681              NaN               NaN                   NaN
# 14682              NaN               NaN                   NaN
# 14683              NaN               NaN                   NaN
# 14684              NaN               NaN                   NaN
#
#        private_sale_long_gun  private_sale_other  return_to_seller_handgun  \
# 0                       34.0                14.0                       0.0
# 1                       18.0                 2.0                       0.0
# 2                       17.0                 3.0                       2.0
# 3                       13.0                 2.0                       1.0
# 4                     2282.0               528.0                      55.0
# ...                      ...                 ...                       ...
# 14680                    NaN                 NaN                       NaN
# 14681                    NaN                 NaN                       NaN
# 14682                    NaN                 NaN                       NaN
# 14683                    NaN                 NaN                       NaN
# 14684                    NaN                 NaN                       NaN
#
#        return_to_seller_long_gun  return_to_seller_other  totals
# 0                            2.0                     0.0  105602
# 1                            0.0                     0.0    9018
# 2                            0.0                     2.0   60548
# 3                            0.0                     0.0   30085
# 4                           33.0                     1.0  134432
# ...                          ...                     ...     ...
# 14680                        NaN                     NaN      24
# 14681                        NaN                     NaN     361
# 14682                        NaN                     NaN     408
# 14683                        NaN                     NaN     241
# 14684                        NaN                     NaN     107
#
# [14685 rows x 27 columns]

# %% [markdown]
# ### Question 1:  Filter the data
#
# In this homework, we will compare the number of background checks in New York and Florida, two states with similar populations (New York: 19.5 million; Florida: 21.5 million).
#
# Create a new DataFrame containing only the rows for Florida and New York.
#
# Hint:  recall that if you have a filter `ny_filter` to select only rows with New York as the state and a filter `fl_filter` to select only rows with Florida, then you can combine them to get only rows that are either New York or Florida with *or* (|):  `new_df = df[ny_filter | fl_filter]`

# %%
ny_filter = guns["state"] == "New York"
fl_filter = guns["state"] == "Florida"
ny_and_fl_guns = guns[ny_filter | fl_filter]
ny_and_fl_guns
# Out:
#            month     state   permit  permit_recheck  handgun  long_gun  \
# 9     2021-01-01   Florida  34470.0             0.0  97406.0   40173.0
# 34    2021-01-01  New York   3664.0          2108.0  12143.0   25221.0
# 64    2020-12-01   Florida  35227.0             0.0  81564.0   40115.0
# 89    2020-12-01  New York   3261.0          1910.0  10486.0   24664.0
# 119   2020-11-01   Florida  35979.0             0.0  84366.0   40575.0
# ...          ...       ...      ...             ...      ...       ...
# 14554 1999-01-01  New York   4616.0             NaN    882.0    5327.0
# 14584 1998-12-01   Florida      0.0             NaN  11188.0   18840.0
# 14609 1998-12-01  New York   1068.0             NaN   1054.0   12234.0
# 14639 1998-11-01   Florida      0.0             NaN    319.0     443.0
# 14664 1998-11-01  New York      0.0             NaN     40.0     279.0
#
#         other  multiple   admin  prepawn_handgun  prepawn_long_gun  \
# 9      6686.0      4549     2.0              6.0               8.0
# 34     4447.0       427     0.0              1.0               1.0
# 64     5594.0      3733     1.0             16.0               5.0
# 89     3145.0       367     0.0              1.0               0.0
# 119    6090.0      4176     2.0             11.0               9.0
# ...       ...       ...     ...              ...               ...
# 14554     NaN        11    61.0              NaN               NaN
# 14584     NaN       337  1164.0              NaN               NaN
# 14609     NaN        12    49.0              NaN               NaN
# 14639     NaN        10    40.0              NaN               NaN
# 14664     NaN         0     0.0              NaN               NaN
#
#        prepawn_other  redemption_handgun  redemption_long_gun  \
# 9                0.0              4116.0               1251.0
# 34               4.0                56.0                 49.0
# 64               0.0              3650.0               1022.0
# 89               2.0                38.0                 56.0
# 119              0.0              2984.0                944.0
# ...              ...                 ...                  ...
# 14554            NaN                 NaN                  NaN
# 14584            NaN                 NaN                  NaN
# 14609            NaN                 NaN                  NaN
# 14639            NaN                 NaN                  NaN
# 14664            NaN                 NaN                  NaN
#
#        redemption_other  returned_handgun  returned_long_gun  returned_other  \
# 9                   7.0            1012.0               84.0            10.0
# 34                 14.0              57.0              102.0             0.0
# 64                 10.0             987.0               95.0            21.0
# 89                  8.0              63.0              128.0             1.0
# 119                 7.0             848.0               78.0            17.0
# ...                 ...               ...                ...             ...
# 14554               NaN               NaN                NaN             NaN
# 14584               NaN               NaN                NaN             NaN
# 14609               NaN               NaN                NaN             NaN
# 14639               NaN               NaN                NaN             NaN
# 14664               NaN               NaN                NaN             NaN
#
#        rentals_handgun  rentals_long_gun  private_sale_handgun  \
# 9                  0.0               0.0                 517.0
# 34                 3.0              12.0                 317.0
# 64                 0.0               0.0                 400.0
# 89                 0.0              10.0                 265.0
# 119                0.0               0.0                 483.0
# ...                ...               ...                   ...
# 14554              NaN               NaN                   NaN
# 14584              NaN               NaN                   NaN
# 14609              NaN               NaN                   NaN
# 14639              NaN               NaN                   NaN
# 14664              NaN               NaN                   NaN
#
#        private_sale_long_gun  private_sale_other  return_to_seller_handgun  \
# 9                      350.0                92.0                      49.0
# 34                     469.0                62.0                       6.0
# 64                     333.0                94.0                      38.0
# 89                     399.0                52.0                       2.0
# 119                    273.0                79.0                      36.0
# ...                      ...                 ...                       ...
# 14554                    NaN                 NaN                       NaN
# 14584                    NaN                 NaN                       NaN
# 14609                    NaN                 NaN                       NaN
# 14639                    NaN                 NaN                       NaN
# 14664                    NaN                 NaN                       NaN
#
#        return_to_seller_long_gun  return_to_seller_other  totals
# 9                           28.0                     1.0  190817
# 34                          19.0                     2.0   49184
# 64                          42.0                     1.0  172948
# 89                          11.0                     1.0   44870
# 119                         27.0                     3.0  176987
# ...                          ...                     ...     ...
# 14554                        NaN                     NaN   10897
# 14584                        NaN                     NaN   31529
# 14609                        NaN                     NaN   14417
# 14639                        NaN                     NaN     812
# 14664                        NaN                     NaN     319
#
# [534 rows x 27 columns]

# %% [markdown]
# ### Question 2: Handgun line plots
#
# a) In Seaborn, create a line plot with two lines showing the number of handgun background checks made in Florida and New York for each month.  How do the number of handgun background checks compare between the two states?

# %%
sns.relplot(x = "month", y = "handgun", hue = "state", kind = "line", data = ny_and_fl_guns)
plt.xlabel("Time")
plt.ylabel("# of hand gun background checks")
plt.title("Hand gun background checks in New York & Florida")
# Out:
# Text(0.5, 1.0, 'Hand gun background checks in New York & Florida')

# %% [markdown]
# From the line plot we can see that Florida has way more handgun background checks compared to New York.

# %% [markdown]
# b)  Using Seaborn, create line plots (on the same graph) of the mean number of handgun background checks for each year for Florida and New York with a 95% confidence interval.  How does this plot differ from the one you made in part (a)?  Which state has the largest 95% confidence interval?  Does this make sense?

# %%
ny_and_fl_guns["year"] = ny_and_fl_guns["month"].dt.year
# Out:
# <ipython-input-8-d97a604708b4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ny_and_fl_guns["year"] = ny_and_fl_guns["month"].dt.year

# %%
sns.relplot(x = "year", y = "handgun", hue = "state", kind = "line",data = ny_and_fl_guns)
plt.xlabel("Time")
plt.ylabel("# of hand gun background checks")
plt.title("Hand gun background checks in New York & Florida")
# Out:
# Text(0.5, 1.0, 'Hand gun background checks in New York & Florida')

# %% [markdown]
# Florida seems to have the largest 95% confindence interval. It doesn't seem to differ from the previous plot I made.

# %% [markdown]
# ### Question 3: Long gun bar chart
#
# Use Seaborn to make a bar chart showing the number of long gun background checks for Florida and New York for each year.  Adjust the figure size and orientation of the axis labels so that the plot is readable.  How do the number of long gun background checks compare between Florida and New York?

# %%
g = sns.catplot(x = "year", y = "long_gun", hue = "state", kind = "bar", data = ny_and_fl_guns)
g.fig.set_size_inches(20,5)
plt.xticks(rotation=45)
plt.xlabel("Time")
plt.ylabel("# of long gun background checks")
plt.title("Long gun background checks in New York & Florida")
# Out:
# Text(0.5, 1.0, 'Long gun background checks in New York & Florida')

# %% [markdown]
# Florida seems to always have more long gun background checks compared to New York.

# %% [markdown]
# ### Question 4: Box plot
#
# Using Seaborn in a single plot, plot boxplots for both Florida and New York of the distribution of the number of long gun background checks made in each month.  That is, the x axis should be the months and the y axis should be the number of long gun background checks.
#
# Do Florida and New York follow the same monthly trends for nubmer of long gun background checks?  Where do they differ?

# %%
ny_and_fl_guns["months"] = ny_and_fl_guns["month"].dt.month
# Out:
# <ipython-input-25-3927b6f32b35>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ny_and_fl_guns["months"] = ny_and_fl_guns["month"].dt.month

# %%
ny_and_fl_guns
# Out:
#            month     state   permit  permit_recheck  handgun  long_gun  \
# 9     2021-01-01   Florida  34470.0             0.0  97406.0   40173.0
# 34    2021-01-01  New York   3664.0          2108.0  12143.0   25221.0
# 64    2020-12-01   Florida  35227.0             0.0  81564.0   40115.0
# 89    2020-12-01  New York   3261.0          1910.0  10486.0   24664.0
# 119   2020-11-01   Florida  35979.0             0.0  84366.0   40575.0
# ...          ...       ...      ...             ...      ...       ...
# 14554 1999-01-01  New York   4616.0             NaN    882.0    5327.0
# 14584 1998-12-01   Florida      0.0             NaN  11188.0   18840.0
# 14609 1998-12-01  New York   1068.0             NaN   1054.0   12234.0
# 14639 1998-11-01   Florida      0.0             NaN    319.0     443.0
# 14664 1998-11-01  New York      0.0             NaN     40.0     279.0
#
#         other  multiple   admin  prepawn_handgun  prepawn_long_gun  \
# 9      6686.0      4549     2.0              6.0               8.0
# 34     4447.0       427     0.0              1.0               1.0
# 64     5594.0      3733     1.0             16.0               5.0
# 89     3145.0       367     0.0              1.0               0.0
# 119    6090.0      4176     2.0             11.0               9.0
# ...       ...       ...     ...              ...               ...
# 14554     NaN        11    61.0              NaN               NaN
# 14584     NaN       337  1164.0              NaN               NaN
# 14609     NaN        12    49.0              NaN               NaN
# 14639     NaN        10    40.0              NaN               NaN
# 14664     NaN         0     0.0              NaN               NaN
#
#        prepawn_other  redemption_handgun  redemption_long_gun  \
# 9                0.0              4116.0               1251.0
# 34               4.0                56.0                 49.0
# 64               0.0              3650.0               1022.0
# 89               2.0                38.0                 56.0
# 119              0.0              2984.0                944.0
# ...              ...                 ...                  ...
# 14554            NaN                 NaN                  NaN
# 14584            NaN                 NaN                  NaN
# 14609            NaN                 NaN                  NaN
# 14639            NaN                 NaN                  NaN
# 14664            NaN                 NaN                  NaN
#
#        redemption_other  returned_handgun  returned_long_gun  returned_other  \
# 9                   7.0            1012.0               84.0            10.0
# 34                 14.0              57.0              102.0             0.0
# 64                 10.0             987.0               95.0            21.0
# 89                  8.0              63.0              128.0             1.0
# 119                 7.0             848.0               78.0            17.0
# ...                 ...               ...                ...             ...
# 14554               NaN               NaN                NaN             NaN
# 14584               NaN               NaN                NaN             NaN
# 14609               NaN               NaN                NaN             NaN
# 14639               NaN               NaN                NaN             NaN
# 14664               NaN               NaN                NaN             NaN
#
#        rentals_handgun  rentals_long_gun  private_sale_handgun  \
# 9                  0.0               0.0                 517.0
# 34                 3.0              12.0                 317.0
# 64                 0.0               0.0                 400.0
# 89                 0.0              10.0                 265.0
# 119                0.0               0.0                 483.0
# ...                ...               ...                   ...
# 14554              NaN               NaN                   NaN
# 14584              NaN               NaN                   NaN
# 14609              NaN               NaN                   NaN
# 14639              NaN               NaN                   NaN
# 14664              NaN               NaN                   NaN
#
#        private_sale_long_gun  private_sale_other  return_to_seller_handgun  \
# 9                      350.0                92.0                      49.0
# 34                     469.0                62.0                       6.0
# 64                     333.0                94.0                      38.0
# 89                     399.0                52.0                       2.0
# 119                    273.0                79.0                      36.0
# ...                      ...                 ...                       ...
# 14554                    NaN                 NaN                       NaN
# 14584                    NaN                 NaN                       NaN
# 14609                    NaN                 NaN                       NaN
# 14639                    NaN                 NaN                       NaN
# 14664                    NaN                 NaN                       NaN
#
#        return_to_seller_long_gun  return_to_seller_other  totals  year  months
# 9                           28.0                     1.0  190817  2021       1
# 34                          19.0                     2.0   49184  2021       1
# 64                          42.0                     1.0  172948  2020      12
# 89                          11.0                     1.0   44870  2020      12
# 119                         27.0                     3.0  176987  2020      11
# ...                          ...                     ...     ...   ...     ...
# 14554                        NaN                     NaN   10897  1999       1
# 14584                        NaN                     NaN   31529  1998      12
# 14609                        NaN                     NaN   14417  1998      12
# 14639                        NaN                     NaN     812  1998      11
# 14664                        NaN                     NaN     319  1998      11
#
# [534 rows x 29 columns]

# %%
g = sns.catplot(x = "months", y = "long_gun", hue = "state", kind = "box", data = ny_and_fl_guns)
g.fig.set_size_inches(20,6)

# %% [markdown]
# It seems like for the monthly trends of long gun background checks Florida still comes out on top.

# %% [markdown]
# ### Question 5: Bivariate plot
#
# Use Seaborn to plot a smoothed bivariate plot of the number of handgun background checks (x) vs. the number of long gun background checks for Florida.
#
# How does this plot compare to the one for New York that we made in Section 5 of Lab 5?

# %%
sns.jointplot(x = "handgun", y = "long_gun", kind = "kde", hue = "state", data = ny_and_fl_guns)

# %% [markdown]
# Note:  If you are using the latest version of Seaborn (which unfortunately is not the one on the Lehman 360 Jupyter Hub), you can use the parameter `hue` in the function `jointplot()` and plot the bivariate distributions for both Florida and New York on the same plot in different colors.

# %% [markdown]
# It seems like New York has more hand gun background checks and Florida has more long gun background checks.
